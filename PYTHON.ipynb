# %% [markdown]
# <a href="https://colab.research.google.com/github/robertolimapr/Python/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1** 🚲 🥷 ✅
#
# ![image.png](data:image/png;base64,...)

# %%
ano = "II"
print(ano, "competição de programação dá Start")
# Out:
# II competição de programação dá Start

# %% [markdown]
# #**Aula 2** 🚲 ⚡ ✅

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais da ana são {pontos_ana}")
print(f"Os pontos totais de ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais da ana são 46
# Os pontos totais de ana e Rodrigo são 70

# %% [markdown]
# #Aula 3 🚲 ☯ 🌫

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))

print(f"João recebeu {figurinhas_joao} figurinhas")

# %% [markdown]
# *Aula 4* 🚲 ⏰ 🤙

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))

def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# *Aula 5* ♣ ♦ ♥

# %%
ef tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero / contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
ef tabuad

# %% [markdown]
# *Aula 6* ☢ ㊙ ⏰

# %%
print("Olá, sou eu assistente virtual")
nome = input("digite seu nome")
print(f"Olá {nome}, em que posso ajudar?")
resposta = input("você deseja falar sobre python, javascript ou matematica:").lower()
if resposta =="python":
  print(f"Ótimo, {nome}, vamos falar sobre Python! \n Python é uma linguagem de programação poderosa, simples e legível, ideal para quem quer transformar ideias em código de forma rápida e elegante")
elif resposta =="matemática":
   print(f"Ótimo, {nome}, vamos falar sobre matematica! \n A matemática é o alicerce invisível que sustenta toda a lógica e a beleza do universo")
elif resposta =="javascript":
   print(f"Ótimo, {nome}, vamos falar sobre javascript! \n JavaScript é a linguagem que dá vida às páginas da web — transforma ideias estáticas em experiências dinâmicas")print("Olá, sou eu assistente virtual")
nome = input("digite seu nome")
print(f"Olá {nome}, em que posso ajudar?")
resposta = input("você deseja falar sobre python, javascript ou matematica:").lower()
if resposta =="python":
  print(f"Ótimo, {nome}, vamos falar sobre Python! \n Python é uma linguagem de programação poderosa, simples e legível, ideal para quem quer transformar ideias em código de forma rápida e elegante")
elif resposta =="matemática":
   print(f"Ótimo, {nome}, vamos falar sobre matematica! \n A matemática é o alicerce invisível que sustenta toda a lógica e a beleza do universo")
elif resposta =="javascript":
   print(f"Ótimo, {nome}, vamos falar sobre javascript! \n JavaScript é a linguagem que dá vida às páginas da web — transforma ideias estáticas em experiências dinâmicas")

# %% [markdown]
# *Aula 7* ❄ ✈ ✅

# %%
import random
dica_do_dia = [
    " 🤓 Comece onde você está, use o que você tem e faça o que você pode",
    " 🫡 A persistência realiza o impossível.",
    " 😏 Acredite em si mesmo e todo o resto virá naturalmente",
    " 🫠 Grandes conquistas começam com pequenas atitudes todos os dias",
    " ☺️ Transforme seus obstáculos em degraus para o sucesso",
    " 🤨 ✊🏿 Descanse o corpo, mas nunca a alma sonhadora.",
    " 🤌🏿 Gratidão pelo que foi, fé no que virá.",
    ]

while True:
    pedido = input("d
        dica = random.choice(dica_do_dia)
        print(f"dica: {dica} \n")
    elif pedido == "sair":
        print("Saindo do programa. Até logo!")
        break
    else:
        print("comando invalido. tente novamente. \n")import random
dica_do_dia = [
    " 🤓 Comece onde você está, use o que você tem e faça o que você pode",
    " 🫡 A persistência realiza o impossível.",
    " 😏 Acredite em si mesmo e todo o resto virá naturalmente",
    " 🫠 Grandes conquistas começam com pequenas atitudes todos os dias",
    " ☺️ Transforme seus obstáculos em degraus para o sucesso",
    " 🤨 ✊🏿 Descanse o corpo, mas nunca a alma sonhadora.",
    " 🤌🏿 Gratidão pelo que foi, fé no que virá.",
    ]

while True:
    pedido = input("digite 'dica' para receber uma dica ou 'sair' para encerrar \n").lower()

    if pedido == "dica":
        dica = random.choice(dica_do_dia)
        print(f"dica: {dica} \n")
    elif pedido == "sair":
        print("Saindo do programa. Até logo!")
        break
    else:
        print("comando invalido. tente novamente. \n")
